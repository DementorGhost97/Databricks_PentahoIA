# %% [markdown]
# #### Ejecución de Notebook Golds_Logs_Analytics_IA

# %%
dbutils.notebook.run(
    "/Workspace/Pentaho_logs_Intelligence/gold/gold_analytics_ia/05_Gold_logs_table_analytics_ai",
    0
)
